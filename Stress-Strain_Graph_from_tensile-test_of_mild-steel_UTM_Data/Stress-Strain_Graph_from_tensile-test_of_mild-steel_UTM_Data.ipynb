# %% [markdown]
# # **Generate Stress vs strain graph from data (In CSV File) of tensile test of a dog bone specimen mild steel.**

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\ErSin\\OneDrive\\Desktop\\mild-stee-tensiletestdatal-nitish-&-monu11.csv",names = ["Force(N)","Changeinlength(mm)","col3"])
data
# Out:
#      Force(N)  Changeinlength(mm)   col3
# 0           0              0.0000    0.0
# 1         481              0.0453   14.3
# 2        1010              0.1540   29.9
# 3        1010              0.1540   29.9
# 4        1090              0.1720   32.3
# ..        ...                 ...    ...
# 994     12000             15.0000  357.0
# 995     11900             15.0000  355.0
# 996     11900             15.1000  353.0
# 997     11800             15.1000  351.0
# 998     11800             15.1000  350.0
#
# [999 rows x 3 columns]

# %%
Stress = []
Force1 = data['Force(N)'].tolist()
CrossSectionArea = 33.6
for y in Force1:
    stress1 = y/CrossSectionArea
    Stress.append(stress1)

print(Stress)
# Out:
# [0.0, 14.31547619047619, 30.059523809523807, 30.059523809523807, 32.44047619047619, 34.523809523809526, 36.607142857142854, 38.988095238095234, 41.07142857142857, 43.154761904761905, 45.238095238095234, 47.32142857142857, 49.404761904761905, 51.19047619047619, 53.27380952380952, 55.357142857142854, 57.44047619047619, 59.52380952380952, 61.607142857142854, 63.69047619047619, 65.77380952380952, 68.1547619047619, 70.23809523809524, 72.32142857142857, 74.70238095238095, 77.08333333333333, 79.46428571428571, 81.84523809523809, 83.92857142857143, 86.30952380952381, 88.69047619047619, 91.36904761904762, 93.75, 96.13095238095238, 98.80952380952381, 101.19047619047619, 103.86904761904762, 106.25, 108.92857142857143, 111.60714285714285, 114.28571428571428, 116.96428571428571, 119.64285714285714, 122.32142857142857, 125.0, 127.97619047619047, 130.6547619047619, 133.33333333333331, 136.3095238095238, 138.98809523809524, 141.96428571428572, 144.94047619047618, 147.61904761904762, 150.595238095238
# ...

# %%
Changeinlength = data['Changeinlength(mm)'].tolist()
Changeinlength
# Out:
# [0.0,
#  0.0453,
#  0.154,
#  0.154,
#  0.172,
#  0.187,
#  0.202,
#  0.217,
#  0.232,
#  0.247,
#  0.263,
#  0.277,
#  0.292,
#  0.307,
#  0.322,
#  0.337,
#  0.352,
#  0.367,
#  0.382,
#  0.397,
#  0.412,
#  0.427,
#  0.442,
#  0.457,
#  0.472,
#  0.487,
#  0.502,
#  0.517,
#  0.532,
#  0.547,
#  0.562,
#  0.577,
#  0.592,
#  0.607,
#  0.622,
#  0.637,
#  0.652,
#  0.667,
#  0.682,
#  0.697,
#  0.712,
#  0.727,
#  0.742,
#  0.757,
#  0.772,
#  0.787,
#  0.802,
#  0.817,
#  0.832,
#  0.847,
#  0.862,
#  0.877,
#  0.892,
#  0.907,
#  0.922,
#  0.937,
#  0.952,
#  0.967,
#  0.982,
#  0.997,
#  1.01,
#  1.03,
#  1.04,
#  1.06,
#  1.07,
#  1.09,
#  1.1,
#  1.12,
#  1.13,
#  1.15,
#  1.16,
#  1.18,
#  1.19,
#  1.21,
#  1.22,
#  1.24,
#  1.25,
#  1.27,
#  1.28,
#  1.3,
#  1.31,
#  1.33,
#  1.34,
#  1.36,
#  1.37,
#  1.39,
#  1.4,
#  1.42,
#  1.43,
#  1.45,
#  1.46,
#  1.48,
#  1.49,
#  1.51,
#  1.52,
#  1.54,
#  1.55,
#  1.57,
#  1.58,
#  1.6,
#  1.61,
#  1.63,
#  1.64,
#  1.66,
#  1.67,
# ...

# %%
Strain = []
Gaugelength = 50 #in mm
for x in Changeinlength:
    strain = x/Gaugelength
    Strain.append(strain)

print(Strain)
# Out:
# [0.0, 0.000906, 0.00308, 0.00308, 0.00344, 0.00374, 0.00404, 0.00434, 0.00464, 0.00494, 0.00526, 0.005540000000000001, 0.00584, 0.00614, 0.00644, 0.00674, 0.007039999999999999, 0.00734, 0.00764, 0.007940000000000001, 0.008239999999999999, 0.008539999999999999, 0.00884, 0.00914, 0.009439999999999999, 0.00974, 0.01004, 0.01034, 0.01064, 0.01094, 0.011240000000000002, 0.01154, 0.01184, 0.01214, 0.01244, 0.01274, 0.013040000000000001, 0.013340000000000001, 0.013640000000000001, 0.01394, 0.01424, 0.014539999999999999, 0.014839999999999999, 0.01514, 0.01544, 0.01574, 0.016040000000000002, 0.01634, 0.01664, 0.01694, 0.01724, 0.01754, 0.01784, 0.01814, 0.01844, 0.01874, 0.019039999999999998, 0.01934, 0.01964, 0.01994, 0.0202, 0.0206, 0.0208, 0.0212, 0.021400000000000002, 0.0218, 0.022000000000000002, 0.022400000000000003, 0.0226, 0.023, 0.0232, 0.0236, 0.023799999999999998, 0.0242, 0.024399999999999998, 0.0248, 0.025, 0.0254, 0.0256, 0.026000000000000002, 0.0262, 0.026600000000000002, 0.0268
# ...

# %%
plt.plot(Strain,Stress , color = "red" )
plt.show()
